# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !pip install pywt
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001A6D4886A60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pywt/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001A6D488C1C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pywt/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001A6D488C280>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pywt/
# ...

# %% [markdown]
# **Filter**

# %% [markdown]
# Glioma

# %%
import cv2
import os
import pywt

# Define the directory where the original images are stored
img_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Training/glioma_tumor'

# Define the directory to save the filtered images
filtered_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Training/filter/glioma_tumor'

# Create the directory if it doesn't exist
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

# Loop through the images in the directory
for file_name in os.listdir(img_dir):
    
    # Load the image
    img_path = os.path.join(img_dir, file_name)
    img = cv2.imread(img_path)
    
    # Apply the Gaussian filter
    img_gaussian = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Apply the median filter
    img_median = cv2.medianBlur(img, 5)
    
    
    # Save the filtered images in the directory
    cv2.imwrite(os.path.join(filtered_dir, 'gaussian_'+file_name), img_gaussian)
    cv2.imwrite(os.path.join(filtered_dir, 'median_'+file_name), img_median)
# Out:
# C:\Users\bhuva\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import cv2
import os
import pywt

# Define the directory where the original images are stored
img_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Testing/glioma_tumor'

# Define the directory to save the filtered images
filtered_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Testing/filter/glioma_tumor'

# Create the directory if it doesn't exist
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

# Loop through the images in the directory
for file_name in os.listdir(img_dir):
    
    # Load the image
    img_path = os.path.join(img_dir, file_name)
    img = cv2.imread(img_path)
    
    # Apply the Gaussian filter
    img_gaussian = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Apply the median filter
    img_median = cv2.medianBlur(img, 5)
    
   
    
    # Save the filtered images in the directory
    cv2.imwrite(os.path.join(filtered_dir, 'gaussian_'+file_name), img_gaussian)
    cv2.imwrite(os.path.join(filtered_dir, 'median_'+file_name), img_median)

# %% [markdown]
# Meningioma

# %%
import cv2
import os
import pywt

# Define the directory where the original images are stored
img_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Training/meningioma_tumor'

# Define the directory to save the filtered images
filtered_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Training/filter/meningioma_tumor'

# Create the directory if it doesn't exist
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

# Loop through the images in the directory
for file_name in os.listdir(img_dir):
    
    # Load the image
    img_path = os.path.join(img_dir, file_name)
    img = cv2.imread(img_path)
    
    # Apply the Gaussian filter
    img_gaussian = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Apply the median filter
    img_median = cv2.medianBlur(img, 5)
    
 
    # Save the filtered images in the directory
    cv2.imwrite(os.path.join(filtered_dir, 'gaussian_'+file_name), img_gaussian)
    cv2.imwrite(os.path.join(filtered_dir, 'median_'+file_name), img_median)

# %%
import cv2
import os
import pywt

# Define the directory where the original images are stored
img_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Testing/meningioma_tumor'

# Define the directory to save the filtered images
filtered_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Testing/filter/meningioma_tumor'

# Create the directory if it doesn't exist
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

# Loop through the images in the directory
for file_name in os.listdir(img_dir):
    
    # Load the image
    img_path = os.path.join(img_dir, file_name)
    img = cv2.imread(img_path)
    
    # Apply the Gaussian filter
    img_gaussian = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Apply the median filter
    img_median = cv2.medianBlur(img, 5)
    
 
    
    # Save the filtered images in the directory
    cv2.imwrite(os.path.join(filtered_dir, 'gaussian_'+file_name), img_gaussian)
    cv2.imwrite(os.path.join(filtered_dir, 'median_'+file_name), img_median)

# %% [markdown]
# Pituitary

# %%
import cv2
import os
import pywt

# Define the directory where the original images are stored
img_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Testing/pituitary_tumor'

# Define the directory to save the filtered images
filtered_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Testing/filter/pituitary_tumor'

# Create the directory if it doesn't exist
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

# Loop through the images in the directory
for file_name in os.listdir(img_dir):
    
    # Load the image
    img_path = os.path.join(img_dir, file_name)
    img = cv2.imread(img_path)
    
    # Apply the Gaussian filter
    img_gaussian = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Apply the median filter
    img_median = cv2.medianBlur(img, 5)
  
    # Save the filtered images in the directory
    cv2.imwrite(os.path.join(filtered_dir, 'gaussian_'+file_name), img_gaussian)
    cv2.imwrite(os.path.join(filtered_dir, 'median_'+file_name), img_median)

# %%
import cv2
import os
import pywt

# Define the directory where the original images are stored
img_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Training/pituitary_tumor'

# Define the directory to save the filtered images
filtered_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Training/filter/pituitary_tumor'

# Create the directory if it doesn't exist
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

# Loop through the images in the directory
for file_name in os.listdir(img_dir):
    
    # Load the image
    img_path = os.path.join(img_dir, file_name)
    img = cv2.imread(img_path)
    
    # Apply the Gaussian filter
    img_gaussian = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Apply the median filter
    img_median = cv2.medianBlur(img, 5)
  
    # Save the filtered images in the directory
    cv2.imwrite(os.path.join(filtered_dir, 'gaussian_'+file_name), img_gaussian)
    cv2.imwrite(os.path.join(filtered_dir, 'median_'+file_name), img_median)

# %% [markdown]
# **Negative**

# %% [markdown]
# Glioma

# %%
import cv2
import os

# Set the input and output directory paths
input_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Training/glioma_tumor'
output_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Training/Negative/glioma_tumor'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # Apply the negative filter
        neg_img = 255 - img
        
        # Save the output image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), neg_img)

# %%
import cv2
import os

# Set the input and output directory paths
input_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Testing/glioma_tumor'
output_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Testing/Negative/glioma_tumor'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # Apply the negative filter
        neg_img = 255 - img
        
        # Save the output image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), neg_img)

# %% [markdown]
# Meningioma

# %%
import cv2
import os

# Set the input and output directory paths
input_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Training/meningioma_tumor'
output_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Training/Negative/meningioma_tumor'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # Apply the negative filter
        neg_img = 255 - img
        
        # Save the output image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), neg_img)

# %%
import cv2
import os

# Set the input and output directory paths
input_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Testing/meningioma_tumor'
output_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Testing/Negative/meningioma_tumor'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # Apply the negative filter
        neg_img = 255 - img
        
        # Save the output image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), neg_img)

# %% [markdown]
# Pituitary

# %%
import cv2
import os

# Set the input and output directory paths
input_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Training/pituitary_tumor'
output_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Training/Negative/pituitary_tumor'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # Apply the negative filter
        neg_img = 255 - img
        
        # Save the output image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), neg_img)

# %%
import cv2
import os

# Set the input and output directory paths
input_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Testing/pituitary_tumor'
output_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Testing/Negative/pituitary_tumor'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # Apply the negative filter
        neg_img = 255 - img
        
        # Save the output image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), neg_img)

# %% [markdown]
# No tumor

# %%
import cv2
import os

# Set the input and output directory paths
input_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Training/no_tumor'
output_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Training/Negative/no_tumor'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # Apply the negative filter
        neg_img = 255 - img
        
        # Save the output image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), neg_img)

# %%
import cv2
import os

# Set the input and output directory paths
input_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Testing/no_tumor'
output_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Testing/Negative/no_tumor'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through each file in the input directory
for filename in os.listdir(input_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(input_dir, filename))
        
        # Apply the negative filter
        neg_img = 255 - img
        
        # Save the output image to the output directory
        cv2.imwrite(os.path.join(output_dir, filename), neg_img)

# %%
import cv2
import os
import pywt

# Define the directory where the original images are stored
img_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Training/no_tumor'

# Define the directory to save the filtered images
filtered_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Training/filter/no_tumor'

# Create the directory if it doesn't exist
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

# Loop through the images in the directory
for file_name in os.listdir(img_dir):
    
    # Load the image
    img_path = os.path.join(img_dir, file_name)
    img = cv2.imread(img_path)
    
    # Apply the Gaussian filter
    img_gaussian = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Apply the median filter
    img_median = cv2.medianBlur(img, 5)
    
   
    
    # Save the filtered images in the directory
    cv2.imwrite(os.path.join(filtered_dir, 'gaussian_'+file_name), img_gaussian)
    cv2.imwrite(os.path.join(filtered_dir, 'median_'+file_name), img_median)

# %%
import cv2
import os
import pywt

# Define the directory where the original images are stored
img_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/Testing/no_tumor'

# Define the directory to save the filtered images
filtered_dir = 'D:/College Study Stuff/Project/Brain Tumor Web/Datasets/Braintumosparseclassification/BrainTumor/Testing/filter/no_tumor'

# Create the directory if it doesn't exist
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

# Loop through the images in the directory
for file_name in os.listdir(img_dir):
    
    # Load the image
    img_path = os.path.join(img_dir, file_name)
    img = cv2.imread(img_path)
    
    # Apply the Gaussian filter
    img_gaussian = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Apply the median filter
    img_median = cv2.medianBlur(img, 5)
    

    
    # Save the filtered images in the directory
    cv2.imwrite(os.path.join(filtered_dir, 'gaussian_'+file_name), img_gaussian)
    cv2.imwrite(os.path.join(filtered_dir, 'median_'+file_name), img_median)
